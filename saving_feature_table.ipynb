# %%
from typing import List, Dict

from oop_functions.experiment_helper import *
from oop_functions.experiment_runner import ExperimentRunner
from oop_functions.util_functions import *
from oop_functions.visualization_util import *
from oop_functions.analytics_cv_util import *
from oop_functions.analytics_utils import *

# %matplotlib inline
import warnings

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import itertools

from dcurves import dca, plot_graphs

# %%
filesuffix = '_for_experiment_participants_screened_single_first_5_RandomForestClassifier_cancer_in_next_1_years__15_trials'

# %%
filename = f'./feature_importance/feature_importance_mean_{filesuffix}.csv'
# print(filename)
feature_list = pd.read_csv(filename)

# %%
cv_analytics_util = CvAnalyticsUtil.load_cv_analytics_utils(filesuffix)

# %%
const_impute_values = cv_analytics_util.analytics_utils[0].data_util.imputer.impute_const_dict

# %%
full_dataset = cv_analytics_util.get_dataset_with_predictions()

# %%
ranges = {}
ranges_numeric = {}
for column in full_dataset.columns:
    try: 
        min_val = full_dataset[column].min()
        max_val = full_dataset[column].max()
        range_str = f'{min_val:.0f} to {max_val:.0f}'
        ranges[column] = range_str
        ranges_numeric[column] = (min_val, max_val)
    except:
        continue

# %%
ranges = pd.DataFrame({
    "column_name": ranges.keys(),
    "Values Range": ranges.values()
})

# %%
const_impute_values = pd.DataFrame({
    "column_name": const_impute_values.keys(),
    "imputed_values": const_impute_values.values()
})

# %%
mean_impute_values = pd.DataFrame({
    "column_name": cv_analytics_util.analytics_utils[0].data_util.imputer.impute_mean_cols,
    # "imputed_values": cv_analytics_util.analytics_utils[0].data_util.imputer.imputer_mean.statistics_
    "imputed_values": ['Mean'] * len(cv_analytics_util.analytics_utils[0].data_util.imputer.impute_mean_cols)
})

# %%
impute_values = pd.concat([const_impute_values, mean_impute_values])

# %%
feature_list = pd.merge(feature_list, impute_values, on='column_name', how='left')

# %%
feature_list = pd.merge(feature_list, ranges, on='column_name', how='left')

# %%
screen_ca125_data_cols = ['ca125ii_level', 'ca125_result', 'ca125ii_level_binary']

# TODO: these have changed
screen_ultra_data_cols = ['detl_p', 'detr_p', 'lvol_p', 'rvol_p', 'lvol_q', 'rvol_q',
       'lantero_p', 'lantero_q', 'llong_p', 'llong_q', 'ltran_p', 'ltran_q',
       'rantero_p', 'rantero_q', 'rlong_p', 'rlong_q', 'rtran_p', 'rtran_q',
       'tvu_ref', 'phycons', 'tvu_result', 'ovar_result',
       'ovcyst_solidr', 'ovcyst_outliner', 'ovcyst_solidl', 'ovcyst_outlinel',
       'ovcyst_solid', 'ovcyst_outline', 'ovcyst_diamr', 'ovcyst_diaml',
       'ovcyst_diam', 'ovcyst_volr', 'ovcyst_voll', 'ovcyst_vol',
       'ovcyst_morphr', 'ovcyst_morphl', 'ovcyst_morph', 'ovcyst_sumr',
       'ovcyst_suml', 'ovcyst_sum', 'ovary_diam', 'ovary_diamr', 'ovary_diaml',
       'ovary_volr', 'ovary_voll', 'ovary_vol', 'visl', 'visr', 'visboth',
       'viseith', 'numcystl', 'numcystr', 'numcyst', 'ovar_days']

screen_abnorm_data_cols = ['solid', 'sepst', 'cyst', 'cystw', 'echo', 'maxdi', 'volum']

screened_cols = ['study_yr', 'plco_id'] + screen_ultra_data_cols + screen_abnorm_data_cols + screen_ca125_data_cols

# %%
feature_list["Description"] = ""
feature_list["Screening vs Demographic"] = "Demographic"

# %%
for index, row in feature_list.iterrows():
    if row['column_name'] in screened_cols:
        feature_list.at[index, 'Screening vs Demographic'] = 'Screening'

# %%
feature_list = feature_list.drop(['count', 'mean', 'percent_missing_after_propagation'], axis=1)

# %%
feature_list
# Out:
#      Unnamed: 0           column_name  percent_missing_before_propagation  \
# 0             0         ca125ii_level                            0.271959
# 1             1  ca125ii_level_binary                            0.267316
# 2             2          ca125_result                            0.000000
# 3             3           ovar_result                            0.000000
# 4             4               tvu_ref                           29.414691
# ..          ...                   ...                                 ...
# 136         136            hispanic_f                            2.891389
# 137         137                 tubal                            0.926651
# 138         138                  pipe                            1.524961
# 139         139                 cigar                            1.702066
# 140         140       post_menopausal                            0.622189
#
#     imputed_values Values Range Description Screening vs Demographic
# 0             Mean    1 to 4980                            Screening
# 1             Mean       1 to 2                            Screening
# 2                9       1 to 9                            Screening
# 3             Mean       1 to 9                            Screening
# 4             Mean       1 to 4                            Screening
# ..             ...          ...         ...                      ...
# 136           Mean       0 to 1                          Demographic
# 137           Mean       0 to 2                          Demographic
# 138           Mean       0 to 2                          Demographic
# 139           Mean       0 to 2                          Demographic
# 140           Mean       1 to 2                          Demographic
#
# [141 rows x 7 columns]

# %%
feature_list.columns = ["Rank", "Column Name", "Missing %", "Imputed Value", "Values Range", "Description", "Screening vs Demographic"]

# %%
feature_list["Rank"] = feature_list["Rank"] + 1

# %%
feature_list = feature_list[["Rank", "Column Name", "Description", "Screening vs Demographic", "Values Range", "Imputed Value", "Missing %"]]

# %%
descriptions = pd.read_csv("./paper_outputs/kept_features_df_description.csv")

# %%
feature_list.to_csv("./paper_outputs/kept_features_df.csv", index=False)

# %%
descriptions = descriptions[:35]

# %%
mean_impute_values = pd.DataFrame({
    "column_name": cv_analytics_util.analytics_utils[0].data_util.imputer.impute_mean_cols,
    "imputed_values": cv_analytics_util.analytics_utils[0].data_util.imputer.imputer_mean.statistics_
    # "imputed_values": ['Mean'] * len(cv_analytics_util.analytics_utils[0].data_util.imputer.impute_mean_cols)
})
impute_values = pd.concat([const_impute_values, mean_impute_values])
impute_values = impute_values.reset_index()
# impute_values = impute_values[impute_values['column_name'].duplicated(keep='last')]
impute_values = {val['column_name']: val['imputed_values'] for key, val in impute_values.to_dict(orient='index').items()}

# %%
def true_false_question_template(column_name, question, default_val):
    default_str = "True"
    if default_val < 0.5:
        default_str = "False"
    return {
        "type": "radiogroup",
        "name": column_name,
        "title": question,
        "choices": ["True", "False"],
        "defaultValue": [default_str]
    }

# %%
def numeric_question_template(column_name, question, min_val, max_val, default_val):
    return {
        "type": "text",
        "name": column_name,
        "title": question,
        "inputType": "number",
        "validators": [
        {
            "type": "numeric",
            "minValue": min_val,
            "maxValue": max_val
        }
        ],
        "defaultValue": [default_val]
    }

# %%
survey = []
for index, row in descriptions.iterrows():
    column_name = row["Column Name"]
    question = f'{row["Description"]}. Values range from {row["Values Range"]}.'
    val_range = ranges_numeric[row["Column Name"]]
    min_val = int(val_range[0])
    max_val = int(val_range[1])
    default_val = int(impute_values[row["Column Name"]])
    if row["Values Range"] in ["0 to 1", "1 to 2"]:
        survey.append(true_false_question_template(column_name, question, default_val))
    else: 
        survey.append(numeric_question_template(column_name, question, min_val, max_val, default_val))

# %%
import json

# %%
json.dumps(survey)
# Out:
# '[{"type": "text", "name": "ca125ii_level", "title": "CA-125 level recorded from a valid screen.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 1, "maxValue": 4980}], "defaultValue": [12]}, {"type": "radiogroup", "name": "ca125ii_level_binary", "title": "Is CA-125 level normal?", "choices": ["True", "False"], "defaultValue": ["True"]}, {"type": "text", "name": "ca125_result", "title": "CA-125 screen result.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 1, "maxValue": 9}], "defaultValue": [9]}, {"type": "text", "name": "ovar_result", "title": "Combined ovarian screening result.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 1, "maxValue": 9}], "defaultValue": [1]}, {"type": "text", "name": "tvu_ref", "title": "The level of referral of TVU exam result.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 1, "maxValue": 4}], "defaultValue": [3]}, {"type": "text", "name": "ovcyst_vol", "title": "The worst volume on any cyst found on either ovary.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 5644}], "defaultValue": [0]}, {"type": "text", "name": "ovary_vol", "title": "The largest ovary volume of the left and right ovary.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 977}], "defaultValue": [2]}, {"type": "text", "name": "ovcyst_sum", "title": "The worst summary of any cyst found on the left ovary. The cyst\'s diamter, solid area, and cyst outline determine the summary of the cyst.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 9}], "defaultValue": [0]}, {"type": "radiogroup", "name": "detl_p", "title": "Sonographically Dectectable Left Side?", "choices": ["True", "False"], "defaultValue": ["False"]}, {"type": "text", "name": "ovcyst_diam", "title": "The worst diameter on any cyst found on either ovary.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 22}], "defaultValue": [1]}, {"type": "text", "name": "ovary_volr", "title": "The right ovary volume.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 977}], "defaultValue": [2]}, {"type": "radiogroup", "name": "detr_p", "title": "Sonographically Dectectable Right Side?", "choices": ["True", "False"], "defaultValue": ["False"]}, {"type": "text", "name": "ovcyst_volr", "title": "The worst volume on any cyst found on the right ovary.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 1176}], "defaultValue": [0]}, {"type": "text", "name": "ovary_diam", "title": "The largest ovary diameter of the left and right ovary (in cm).", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 13}], "defaultValue": [1]}, {"type": "text", "name": "ovcyst_diamr", "title": "The worst diameter on any cyst found on the right ovary.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 13}], "defaultValue": [0]}, {"type": "text", "name": "bmi_curr", "title": "BMI at Baseline", "inputType": "number", "validators": [{"type": "numeric", "minValue": 15, "maxValue": 73}], "defaultValue": [26]}, {"type": "text", "name": "rantero_p", "title": "Ovary Size - Antereoposterior Right in mm", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 131}], "defaultValue": [12]}, {"type": "text", "name": "ovcyst_morph", "title": "The worst morphology of any cyst found on either ovary. The cyst\'s solid area and cyst outline determine the morphology of the cyst.", "inputType": "number", "validators": [{"type": "numeric", "minValue": 0, "maxValue": 3}], "defaultValue": [0]}, {"type": "text", "name": "tvu_result", "title": "TVU Result", "inputType": "number", "validators": [{"type": "numeric", "minValue": 1, "maxValue": 9}], "defaultValue": [9]}, {"type": "text", "name": "bmi_50", "title": "BMI at Age 50", "inputT ...

# %%
file_path = "./paper_outputs/survey.json"
with open(file_path, 'w') as json_file:
    json.dump(survey, json_file)

# %%
descriptions
# Out:
#     Rank           Column Name  \
# 0      1         ca125ii_level
# 1      2  ca125ii_level_binary
# 2      3          ca125_result
# 3      4           ovar_result
# 4      5               tvu_ref
# 5      6            ovcyst_vol
# 6      7             ovary_vol
# 7      8            ovcyst_sum
# 8      9                detl_p
# 9     10           ovcyst_diam
# 10    11            ovary_volr
# 11    12                detr_p
# 12    13           ovcyst_volr
# 13    14            ovary_diam
# 14    15          ovcyst_diamr
# 15    16              bmi_curr
# 16    17             rantero_p
# 17    18          ovcyst_morph
# 18    19            tvu_result
# 19    20                bmi_50
# 20    21              weight_f
# 21    22            weight50_f
# 22    23                bmi_20
# 23    24            ovary_voll
# 24    25          ovcyst_diaml
# 25    26           ovcyst_voll
# 26    27             lantero_p
# 27    28            weight20_f
# 28    29                 volum
# 29    30                  visl
# 30    31           ovary_diamr
# 31    32               rlong_p
# 32    33               viseith
# 33    34               rtran_p
# 34    35                 maxdi
#
#                                           Description  \
# 0          CA-125 level recorded from a valid screen.
# 1                             Is CA-125 level normal?
# 2                               CA-125 screen result.
# 3                  Combined ovarian screening result.
# 4           The level of referral of TVU exam result.
# 5   The worst volume on any cyst found on either o...
# 6   The largest ovary volume of the left and right...
# 7   The worst summary of any cyst found on the lef...
# 8              Sonographically Dectectable Left Side?
# 9   The worst diameter on any cyst found on either...
# 10                            The right ovary volume.
# 11            Sonographically Dectectable Right Side?
# 12  The worst volume on any cyst found on the righ...
# 13  The largest ovary diameter of the left and rig...
# 14  The worst diameter on any cyst found on the ri...
# 15                                    BMI at Baseline
# 16          Ovary Size - Antereoposterior Right in mm
# 17  The worst morphology of any cyst found on eith...
# 18                                         TVU Result
# 19                                      BMI at Age 50
# 20                           Weight (lbs) at Baseline
# 21                             Weight at Age 50 (lbs)
# 22                                      BMI at Age 20
# 23                             The left ovary volume.
# 24  The worst diameter on any cyst found on the le...
# 25                             The left ovary volume.
# 26      Ovary Size - Antereoposterior Left Side in mm
# 27                             Weight at Age 20 (lbs)
# 28                                     Volume of Cyst
# 29  Was the left ovary sonographically detectable?...
# 30                          The right ovary diameter.
# 31  Was either ovary sonographically detectable? C...
# 32            Sonographically Detectable Either Side?
# 33  Ovary Size - Transverse Diameter Right Side in mm
# 34                                   Maximum Diameter
#
#    Screening vs Demographic Values Range Imputed Value  Missing %
# 0                 Screening    1 to 4980          Mean        0.3
# 1                 Screening       1 to 2          Mean        0.3
# 2                 Screening       1 to 9             9        0.0
# 3                 Screening       1 to 9          Mean        0.0
# 4                 Screening       1 to 4          Mean       29.4
# 5                 Screening    0 to 5644             0       61.8
# 6                 Screening     0 to 977          Mean       62.3
# 7                 Screening       0 to 9             0        0.0
# 8                 Screening       0 to 1          Mean       29.7
# 9                 Screening      0 to 22          Mean       61.8
# 10                Screening     0 to 977          Mean       70.3
# 11                Screening       0 to 1          Mean       29.7
# 12                Screening    0 to 1176             0       70.0
# 13                Screening      0 to 14          Mean       62.3
# 14                Screening      0 to 14             0       70.0
# 15              Demographic     15 to 73          Mean        1.6
# 16                Screening     0 to 131          Mean       70.4
# 17                Screening       0 to 3             0        0.0
# 18                Screening       1 to 9             9        0.0
# 19              Demographic     15 to 66          Mean        1.5
# 20              Demographic    70 to 378          Mean        1.4
# 21              Demographic    80 to 399          Mean        1.2
# 22              Demographic     15 to 60          Mean        1.8
# 23                Screening     0 to 470          Mean       71.1
# 24                Screening      0 to 22             0       70.7
# 25                Screening    0 to 5644             0       70.7
# 26                Screening      0 to 90          Mean       71.1
# 27              Demographic    74 to 399          Mean        1.6
# 28                Screening    0 to 5000          Mean       91.6
# 29                Screening       0 to 1             0        0.0
# 30                Screening      0 to 14          Mean       70.3
# 31                Screening     0 to 137          Mean       70.4
# 32                Screening       0 to 1             0        0.0
# 33                Screening     0 to 127          Mean       70.4
# 34                Screening      0 to 22          Mean       91.5
