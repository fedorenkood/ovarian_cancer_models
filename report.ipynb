# %%
from typing import List

from oop_functions.experiment_helper import *
from oop_functions.experiment_runner import ExperimentRunner
from oop_functions.util_functions import summarize_features, print_df
from oop_functions.visualization_util import *
from oop_functions.analytics_cv_util import *

# %matplotlib inline
import warnings

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

from xgboost import XGBClassifier

import itertools

# %%
filesuffix = 'experiment_not_screened_cols_XGBClassifier_for_cancer_in_next_1_years_10_trials'
cv_analytics_util = CvAnalyticsUtil.load_cv_analytics_utils(filesuffix)
cv_analytics_util.store_cv_results();
cv_analytics_util.display_graph()
# Out:
# Cross-Validation measures:
# +--------------------+------------+-------+------------+------------+
# |                    |       mean |   std |        min |        max |
# |--------------------+------------+-------+------------+------------|
# | precision__class_0 | 0.999282   |   nan | 0.999282   | 0.999282   |
# | recall__class_0    | 0.873462   |   nan | 0.873462   | 0.873462   |
# | f1-score__class_0  | 0.932146   |   nan | 0.932146   | 0.932146   |
# | precision__class_1 | 0.00591619 |   nan | 0.00591619 | 0.00591619 |
# | recall__class_1    | 0.545455   |   nan | 0.545455   | 0.545455   |
# | f1-score__class_1  | 0.0117054  |   nan | 0.0117054  | 0.0117054  |
# | accuracy           | 0.87301    |   nan | 0.87301    | 0.87301    |
# | auc                | 0.853216   |   nan | 0.853216   | 0.853216   |
# +--------------------+------------+-------+------------+------------+
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
filesuffix = 'experiment_participants_screened_first_5_XGBClassifier_for_cancer_in_next_1_years_15_trials'
cv_analytics_util = CvAnalyticsUtil.load_cv_analytics_utils(filesuffix)
cv_analytics_util.store_cv_results();
cv_analytics_util.display_graph()
# Out:
# Cross-Validation measures:
# +--------------------+-----------+-------------+-----------+----------+
# |                    |      mean |         std |       min |      max |
# |--------------------+-----------+-------------+-----------+----------|
# | precision__class_0 | 0.999621  | 0.000222342 | 0.999018  | 0.999824 |
# | recall__class_0    | 0.996385  | 0.000626125 | 0.995206  | 0.997361 |
# | f1-score__class_0  | 0.998     | 0.000319626 | 0.997384  | 0.998591 |
# | precision__class_1 | 0.0974921 | 0.0570506   | 0.0181818 | 0.219512 |
# | recall__class_1    | 0.498325  | 0.216855    | 0.153846  | 0.777778 |
# | f1-score__class_1  | 0.160312  | 0.0878196   | 0.0327869 | 0.327273 |
# | accuracy           | 0.99601   | 0.000636953 | 0.994782  | 0.997187 |
# | auc                | 0.960211  | 0.0306716   | 0.893235  | 0.99491  |
# +--------------------+-----------+-------------+-----------+----------+
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
filesuffix = 'experiment_participants_screened_cols_first_5_XGBClassifier_for_cancer_in_next_1_years_15_trials'
cv_analytics_util = CvAnalyticsUtil.load_cv_analytics_utils(filesuffix)
cv_analytics_util.store_cv_results();
cv_analytics_util.display_graph()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Data\coding_projects\ovarian_cancer_models\report.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Data/coding_projects/ovarian_cancer_models/report.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> filesuffix = 'experiment_participants_screened_cols_first_5_XGBClassifier_for_cancer_in_next_1_years_15_trials'
#       <a href='vscode-notebook-cell:/c%3A/Data/coding_projects/ovarian_cancer_models/report.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> cv_analytics_util = CvAnalyticsUtil.load_cv_analytics_utils(filesuffix)
# ----> <a href='vscode-notebook-cell:/c%3A/Data/coding_projects/ovarian_cancer_models/report.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> cv_analytics_util.store_cv_results();
#       <a href='vscode-notebook-cell:/c%3A/Data/coding_projects/ovarian_cancer_models/report.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> cv_analytics_util.display_graph()
#
# File c:\Data\coding_projects\ovarian_cancer_models\oop_functions\analytics_cv_util.py:214, in FeatureImportanceCvAnalyticsUtil.store_cv_results(self)
#     213 def store_cv_results(self) -> None:
# --> 214     super(FeatureImportanceCvAnalyticsUtil, self).store_cv_results()
#     215     df_feature_importance_mean_describe = self.get_cv_feature_selection()
#     216     df_feature_importance_mean_describe.to_csv(
#     217         f'./feature_importance/feature_importance_mean_{self.get_file_suffix()}.csv')
#
# File c:\Data\coding_projects\ovarian_cancer_models\oop_functions\analytics_cv_util.py:162, in CvAnalyticsUtil.store_cv_results(self)
#     160 def store_cv_results(self) -> None:
#     161     # I assume that all of the analytics_utils have the same classifier type
# --> 162     cv_scores, measures_df = self.get_cv_report()
#     163     cv_scores.to_csv(f'./cv_scores/cv_scores_{self.get_file_suffix()}.csv')
#     164     measures_df.to_csv(f'./cv_scores/cv_stats_{self.get_file_suffix()}.csv')
#
# File c:\Data\coding_projects\ovarian_cancer_models\oop_functions\analytics_cv_util.py:47, in CvAnalyticsUtil.get_cv_report(self)
#      45 cv_scores = []
#      46 for k, analytics_util in enumerate(self.analytics_utils):
# ---> 47     report_generation_util = analytics_util.get_report_generation_util_filtered(self.filter)
#      48     if self.threshold:
#      49         report_generation_util.apply_threshold(self.threshold)
#
# File c:\Data\coding_projects\ovarian_cancer_models\oop_functions\analytics_util.py:73, in AnalyticsUtil.get_report_generation_util_filtered(self, filter)
#      71 def get_report_generation_util_filtered(self, filter: Callable[[pd.DataFrame], pd.DataFrame]) -> GenerateReportUtil:
#      72     if filter is None:
# ---> 73         return self.get_report_generation_util()
#      74     X_test, y_test = self.data_util.get_filtered_test_data(filter)
#      75     y_pred, y_prob = self.get_predictions_general(X_test)
#
# File c:\Data\coding_projects\ovarian_cancer_models\oop_functions\analytics_util.py:68, in AnalyticsUtil.get_report_generation_util(self)
#      66 def get_report_generation_util(self) -> GenerateReportUtil:
#      67     X_test, y_test = self.data_util.get_test_data()
# ---> 68     y_pred, y_prob = self.get_predictions()
#      69     return GenerateReportUtil(y_test, y_pred, y_prob)
#
# File c:\Data\coding_projects\ovarian_cancer_models\oop_functions\analytics_util.py:57, in AnalyticsUtil.get_predictions(self)
#      55 def get_predictions(self) -> Tuple[np.array, np.array]:
#      56     X_test, y_test = self.data_util.get_test_data()
# ---> 57     return self.get_predictions_general(X_test)
#
# File c:\Data\coding_projects\ovarian_cancer_models\oop_functions\analytics_util.py:51, in AnalyticsUtil.get_predictions_general(self, X_test)
#      50 def get_predictions_general(self, X_test: pd.DataFrame) -> Tuple[np.array, np.array]:
# ---> 51     y_pred = self.classifier.predict(X_test)
#      52     y_prob = self.classifier.predict_proba(X_test)[:, 1]
#      53     return y_pred, y_prob
#
# File c:\Users\fedor\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:1551, in XGBClassifier.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1541 def predict(
#    1542     self,
#    1543     X: ArrayLike,
#    (...)
#    1548     iteration_range: Optional[Tuple[int, int]] = None,
#    1549 ) -> np.ndarray:
#    1550     with config_context(verbosity=self.verbosity):
# -> 1551         class_probs = super().predict(
#    1552             X=X,
#    1553             output_margin=output_margin,
#    1554             ntree_limit=ntree_limit,
#    1555             validate_features=validate_features,
#    1556             base_margin=base_margin,
#    1557             iteration_range=iteration_range,
#    1558         )
#    1559         if output_margin:
#    1560             # If output_margin is active, simply return the scores
#    1561             return class_probs
#
# File c:\Users\fedor\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:1140, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1138 if self._can_use_inplace_predict():
#    1139     try:
# -> 1140         predts = self.get_booster().inplace_predict(
#    1141             data=X,
#    1142             iteration_range=iteration_range,
#    1143             predict_type="margin" if output_margin else "value",
#    1144             missing=self.missing,
#    1145             base_margin=base_margin,
#    1146             validate_features=validate_features,
#    1147         )
#    1148         if _is_cupy_array(predts):
#    1149             import cupy  # pylint: disable=import-error
#
# File c:\Users\fedor\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:2268, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2264         raise TypeError(
#    2265             "`shape` attribute is required when `validate_features` is True."
#    2266         )
#    2267     if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 2268         raise ValueError(
#    2269             f"Feature shape mismatch, expected: {self.num_features()}, "
#    2270             f"got {data.shape[1]}"
#    2271         )
#    2273 from .data import (
#    2274     _array_interface,
#    2275     _is_cudf_df,
#    (...)
#    2278     _transform_pandas_df,
#    2279 )
#    2281 enable_categorical = _has_categorical(self, data)
#
# ValueError: Feature shape mismatch, expected: 60, got 61

# %%
filesuffix = 'experiment_screened_cols_XGBClassifier_for_cancer_in_next_1_years_15_trials'
cv_analytics_util = CvAnalyticsUtil.load_cv_analytics_utils(filesuffix)
cv_analytics_util.store_cv_results();
cv_analytics_util.display_graph()
# Out:
# Cross-Validation measures:
# +--------------------+------------+-------------+------------+------------+
# |                    |       mean |         std |        min |        max |
# |--------------------+------------+-------------+------------+------------|
# | precision__class_0 | 0.999235   | 0.000141748 | 0.998957   | 0.999426   |
# | recall__class_0    | 0.945454   | 0.00906039  | 0.931346   | 0.959867   |
# | f1-score__class_0  | 0.97158    | 0.00478115  | 0.964186   | 0.97921    |
# | precision__class_1 | 0.00298635 | 0.00153026  | 0.00101317 | 0.00645161 |
# | recall__class_1    | 0.181152   | 0.0789408   | 0.0526316  | 0.315789   |
# | f1-score__class_1  | 0.00587137 | 0.0029944   | 0.00198807 | 0.0125984  |
# | accuracy           | 0.944779   | 0.00904259  | 0.930855   | 0.95927    |
# | auc                | 0.553032   | 0.0816007   | 0.333148   | 0.691701   |
# +--------------------+------------+-------------+------------+------------+
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
